# %%
import pandas as pd
import numpy as np
import os

DATA_PATH = r"C:\Users\Local user\IITDelhi Hackathon\IITD-Tryst-Hackathon\data"

# %%
customers = pd.read_csv(os.path.join(DATA_PATH, "customers.csv"))
accounts = pd.read_csv(os.path.join(DATA_PATH, "accounts.csv"))
linkage = pd.read_csv(os.path.join(DATA_PATH, "customer_account_linkage.csv"))
products = pd.read_csv(os.path.join(DATA_PATH, "product_details.csv"))
labels = pd.read_csv(os.path.join(DATA_PATH, "train_labels.csv"))
test_accounts = pd.read_csv(os.path.join(DATA_PATH, "test_accounts.csv"))

transactions = pd.concat(
    [pd.read_csv(os.path.join(DATA_PATH, f"transactions_part_{i}.csv")) for i in range(6)],
    ignore_index=True
)

print("Loaded successfully")
# Out:
# Loaded successfully

# %%
customers
# Out:
#        customer_id date_of_birth relationship_start_date pan_available  \
# 0      CUST_000001    1992-12-26              2008-04-09             Y
# 1      CUST_000006    1950-05-01              2005-08-01             Y
# 2      CUST_000041    1992-01-01              2013-11-22           NaN
# 3      CUST_000051    1957-01-25              2020-08-12           NaN
# 4      CUST_000059    1987-05-08              2023-10-17             Y
# ...            ...           ...                     ...           ...
# 39983  CUST_198985    1953-12-01              2011-10-27             Y
# 39984  CUST_198989    2003-04-04              2006-10-22             Y
# 39985  CUST_198990    2006-07-04              2010-01-22           NaN
# 39986  CUST_198996    1982-07-05              1997-11-08             Y
# 39987  CUST_198997    1986-03-06              2014-01-01             Y
#
#       aadhaar_available passport_available mobile_banking_flag  \
# ...
